# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Comparing accuracy with different percentage of trajectory with speed = 0

# %%
df = pd.read_pickle("acc_90p_0_lane_filter_f1.pkl")

# %% [markdown]
# #### F1 Score: trajectories with speed > 0 90% of time

# %%
df1 = df.loc[(slice(None),['f1_score','traj_len'],slice(None))]
df1
# Out:
#                                   50      100     150     200     250     300  \
# Random Forest  f1_score mean   59.003  58.755  56.423    56.2   57.55  56.921
#                         std     0.814   1.048   1.817   1.861   1.972   3.099
# AdaBoost       f1_score mean    56.62   55.26  55.512   54.92   54.06  55.266
#                         std     1.114   1.124   1.346   1.042   2.316   1.849
# SVM            f1_score mean    44.53  36.929  23.794  25.687  27.857   19.74
#                         std     0.934   2.984   3.794   2.514    8.24   3.545
# Log Regression f1_score mean   54.356  53.671  52.059  53.996  53.623  53.016
#                         std     0.879   0.748   1.475   3.131    1.49   1.201
# traj_len       traj_len total   18598    8596    5298    3670    2710    2090
#                         Car      9299    4298    2649    1835    1355    1045
#                         Taxi     9299    4298    2649    1835    1355    1045
#
#                                   350     400     450     500     550     600  \
# Random Forest  f1_score mean   56.626  60.154  59.286  58.163  56.895  60.359
#                         std     3.485    4.09   1.375   2.979   3.031   5.577
# AdaBoost       f1_score mean   56.043  55.871  55.509  54.506  52.773  56.298
#                         std     3.019   4.523   3.877   5.257   4.792   6.404
# SVM            f1_score mean   28.541  22.376  25.736   22.11  24.751  24.699
#                         std     4.983   7.752   9.108   2.554  10.071     8.2
# Log Regression f1_score mean   55.956  55.486  55.645  56.243   56.44  56.611
#                         std      0.88   4.454   1.732   3.844     4.0   6.525
# traj_len       traj_len total    1654    1298    1044     832     694     596
#                         Car       827     649     522     416     347     298
#                         Taxi      827     649     522     416     347     298
#
#                                   650     700     750     800     850
# Random Forest  f1_score mean   53.736  54.316  51.349   55.78  53.136
#                         std     5.098   3.264   3.385   7.961   8.935
# AdaBoost       f1_score mean   54.762  57.067  53.023  55.393  60.229
#                         std     6.232   3.791   2.665   4.981   7.788
# SVM            f1_score mean   27.725  12.221   30.88  37.398  36.953
#                         std    11.138   6.216   7.957   4.547    8.87
# Log Regression f1_score mean   53.165  54.493  48.673    47.8  52.589
#                         std     7.082   3.608   3.409  12.052   7.885
# traj_len       traj_len total     474     420     360     298     250
#                         Car       237     210     180     149     125
#                         Taxi      237     210     180     149     125

# %%
fig,ax = plt.subplots(2)
df1 = df.loc[(slice(None),'f1_score',slice(None))]
fig.set_size_inches(8,10)
fig.set_dpi(80)
fig.tight_layout(h_pad=3)
fig.suptitle('F1_score vs. Trajectory Length')
plt.subplots_adjust(top=0.90)
model_keys = df1.index.get_level_values(0).unique()[0:4]

ax_mean, ax_std = ax

ax_mean.set_ylabel('Mean')
ax_std.set_ylabel('Std')

for i,name in enumerate(model_keys):
    ax_mean.plot(df1.columns, df1.loc[(name, 'mean')])
    ax_std.plot(df1.columns, df1.loc[(name, 'std')])

fig.legend(model_keys)
plt.show()

# %% [markdown]
# #### Accuracy: trajectories with speed > 0 90% of time

# %%
df1 = df.loc[(slice(None),['accuracy','traj_len'],slice(None))]
df1
# Out:
#                                   50      100     150     200     250     300  \
# Random Forest  accuracy mean   59.571  59.109  56.719  56.703  58.192  57.751
#                         std      0.81   0.633   1.292   1.658   1.975   2.185
# AdaBoost       accuracy mean   58.872  57.585  56.946  56.621  55.867  56.746
#                         std     0.837    1.21   1.108   0.869    1.45   2.432
# SVM            accuracy mean   54.888  53.037  51.831  52.398  51.365  51.962
#                         std     0.715    1.18   1.489   0.898    0.38   1.486
# Log Regression accuracy mean   57.318  56.422  55.455  57.003  55.793  56.364
#                         std     0.553   0.832   1.148   2.287   1.048   1.097
# traj_len       traj_len total   18598    8596    5298    3670    2710    2090
#                         Car      9299    4298    2649    1835    1355    1045
#                         Taxi     9299    4298    2649    1835    1355    1045
#
#                                   350     400     450     500     550     600  \
# Random Forest  accuracy mean   56.529  60.244  60.247  58.779  58.214  61.915
#                         std     1.316   3.505   2.024   3.014   3.984   2.763
# AdaBoost       accuracy mean   56.527  56.856  56.517  55.764  54.179  58.231
#                         std     2.899   3.538   3.164   4.573   4.254   5.474
# SVM            accuracy mean   51.934  50.771  52.873  52.884   51.58  50.679
#                         std     1.179   1.656   1.586   0.976   3.344   3.106
# Log Regression accuracy mean   58.222    56.7   57.76  58.054  57.341  59.057
#                         std     0.987   4.026   0.993   2.921   3.827   5.502
# traj_len       traj_len total    1654    1298    1044     832     694     596
#                         Car       827     649     522     416     347     298
#                         Taxi      827     649     522     416     347     298
#
#                                   650     700     750     800    850
# Random Forest  accuracy mean   54.634  56.429    52.5  56.678   56.8
#                         std     4.872   2.673   5.372     8.6    6.4
# AdaBoost       accuracy mean   56.336  57.143  54.167  55.418   61.6
#                         std     4.814   3.765    4.12   6.347  6.248
# SVM            accuracy mean   50.412  50.476  55.278  56.011   58.8
#                         std     3.143   1.615   3.216   6.868  4.118
# Log Regression accuracy mean   55.059  55.952  51.667  54.045   56.4
#                         std     3.217   3.912   4.064   4.612  4.964
# traj_len       traj_len total     474     420     360     298    250
#                         Car       237     210     180     149    125
#                         Taxi      237     210     180     149    125

# %%
fig,ax = plt.subplots(2)
df1 = df.loc[(slice(None),'accuracy',slice(None))]
fig.set_size_inches(8,10)
fig.set_dpi(80)
fig.tight_layout(h_pad=3)
fig.suptitle('Accuracy vs. Trajectory Length')
plt.subplots_adjust(top=0.90)
model_keys = df1.index.get_level_values(0).unique()
ax_mean, ax_std = ax

ax_mean.set_ylabel('Mean')
ax_std.set_ylabel('Std')

for i,name in enumerate(model_keys):
    ax_mean.plot(df1.columns, df1.loc[(name, 'mean')])
    ax_std.plot(df1.columns, df1.loc[(name, 'std')])

fig.legend(model_keys)
plt.show()

# %%
df = pd.read_pickle("acc_75p_0_lane_filter_f1.pkl")

# %% [markdown]
# #### F1 Score: trajectories with speed > 0 75% of time

# %%
df1 = df.loc[(slice(None),['f1_score','traj_len'],slice(None))]
df1
# Out:
#                                   50      100     150     200     250     300  \
# Random Forest  f1_score mean   58.365  57.578  57.254  57.851  54.648  57.698
#                         std     0.404   0.308   1.149   0.967   0.613   2.001
# AdaBoost       f1_score mean   56.759  55.548  55.289  55.289  55.747  56.391
#                         std     1.208   1.306   1.046    0.88   2.194   1.697
# SVM            f1_score mean   43.609  36.184  24.783  31.778  23.502  20.517
#                         std     1.295   4.097   2.706   3.452   4.427   4.355
# Log Regression f1_score mean   54.232  54.181  53.442  54.381  52.636  52.334
#                         std     0.658   1.186    1.14   2.979   2.266   1.814
# traj_len       traj_len total   18866    8906    5590    3996    2994    2394
#                         Car      9433    4453    2795    1998    1497    1197
#                         Taxi     9433    4453    2795    1998    1497    1197
#
#                                   350     400     450     500     550     600  \
# Random Forest  f1_score mean   55.013  58.714  56.382  57.463  55.556   56.16
#                         std     2.386   2.728   1.955   2.424    4.35   5.598
# AdaBoost       f1_score mean    53.05  56.551   52.18  53.765  53.946  55.906
#                         std      3.28   3.633    0.84   3.764    2.19    4.25
# SVM            f1_score mean   34.781  28.491  20.758  22.879  17.257  24.753
#                         std     5.149   3.608   3.847   8.523   5.518   10.61
# Log Regression f1_score mean    54.82  53.683  52.337  54.113  57.282  52.552
#                         std     2.343   2.844   2.191    2.39   3.764     5.1
# traj_len       traj_len total    1934    1602    1350    1104     956     850
#                         Car       967     801     675     552     478     425
#                         Taxi      967     801     675     552     478     425
#
#                                   650     700     750     800     850
# Random Forest  f1_score mean   54.842  58.789  54.491  53.149  57.039
#                         std     4.805   4.462   3.366   5.613   7.045
# AdaBoost       f1_score mean   53.889  57.684  57.032  55.464  54.502
#                         std     3.937   4.759   4.101   1.689   2.591
# SVM            f1_score mean   23.433  11.747  13.655  30.347  11.487
#                         std     9.028   3.757   9.143  10.698  10.616
# Log Regression f1_score mean   54.183  52.926  49.557  52.172  51.718
#                         std       3.7   4.247   5.236   6.327   2.169
# traj_len       traj_len total     696     610     530     474     420
#                         Car       348     305     265     237     210
#                         Taxi      348     305     265     237     210

# %%
fig,ax = plt.subplots(2)
df1 = df.loc[(slice(None),'f1_score',slice(None))]
fig.set_size_inches(8,10)
fig.set_dpi(80)
fig.tight_layout(h_pad=3)
fig.suptitle('F1_score vs. Trajectory Length')
plt.subplots_adjust(top=0.90)
model_keys = df1.index.get_level_values(0).unique()[0:4]

ax_mean, ax_std = ax

ax_mean.set_ylabel('Mean')
ax_std.set_ylabel('Std')

for i,name in enumerate(model_keys):
    ax_mean.plot(df1.columns, df1.loc[(name, 'mean')])
    ax_std.plot(df1.columns, df1.loc[(name, 'std')])

fig.legend(model_keys)
plt.show()

# %% [markdown]
# #### Accuracy: trajectories with speed > 0 75% of time

# %%
df1 = df.loc[(slice(None),['accuracy','traj_len'],slice(None))]
df1
# Out:
#                                   50      100     150     200     250     300  \
# Random Forest  accuracy mean   58.984   58.32  57.603  58.008  55.177  57.603
#                         std     0.356   0.431   1.897   0.579   0.683   1.516
# AdaBoost       accuracy mean   58.863  57.736  57.102  56.481  56.648  57.729
#                         std     0.922   0.822   0.906   1.168   1.708   2.169
# SVM            accuracy mean   54.712  53.133  51.449  52.677   51.97  51.671
#                         std     0.825   0.819   0.621   1.596   1.526   2.247
# Log Regression accuracy mean   57.256  57.074  57.048  57.358  55.679  55.221
#                         std     0.332   1.013   0.417   2.066   1.469    2.23
# traj_len       traj_len total   18866    8906    5590    3996    2994    2394
#                         Car      9433    4453    2795    1998    1497    1197
#                         Taxi     9433    4453    2795    1998    1497    1197
#
#                                   350     400     450     500     550     600  \
# Random Forest  accuracy mean   55.842  59.424  56.444  58.422  56.484  57.647
#                         std     0.922    2.34    2.05   2.573   2.913    3.43
# AdaBoost       accuracy mean    54.86  57.802  54.074   54.53  55.753  56.941
#                         std     2.827   2.976    2.16   2.792   2.564   3.518
# SVM            accuracy mean   53.463  52.872  51.185  53.352  51.569  50.118
#                         std     1.572   1.993   1.743   2.115   2.133   3.728
# Log Regression accuracy mean   57.395  57.242  56.815  57.246  58.891  55.294
#                         std     1.527   2.142   2.278   2.959   3.243   3.389
# traj_len       traj_len total    1934    1602    1350    1104     956     850
#                         Car       967     801     675     552     478     425
#                         Taxi      967     801     675     552     478     425
#
#                                   650     700     750     800     850
# Random Forest  accuracy mean   56.893  60.164   57.17  53.794  57.381
#                         std     5.484     5.2   3.848   4.985   5.754
# AdaBoost       accuracy mean   54.172  58.525   57.17  55.908  55.238
#                         std     3.372   3.049   2.503   2.912   2.564
# SVM            accuracy mean   52.004  51.639  52.075  52.739  52.143
#                         std     2.668   0.733    2.76   2.314   2.955
# Log Regression accuracy mean   56.472  56.557  53.208  54.199  54.762
#                         std     2.392   3.067   4.645   5.822   1.304
# traj_len       traj_len total     696     610     530     474     420
#                         Car       348     305     265     237     210
#                         Taxi      348     305     265     237     210

# %%
fig,ax = plt.subplots(2)
df1 = df.loc[(slice(None),'accuracy',slice(None))]
fig.set_size_inches(8,10)
fig.set_dpi(80)
fig.tight_layout(h_pad=3)
fig.suptitle('Accuracy vs. Trajectory Length')
plt.subplots_adjust(top=0.90)
model_keys = df1.index.get_level_values(0).unique()
ax_mean, ax_std = ax

ax_mean.set_ylabel('Mean')
ax_std.set_ylabel('Std')

for i,name in enumerate(model_keys):
    ax_mean.plot(df1.columns, df1.loc[(name, 'mean')])
    ax_std.plot(df1.columns, df1.loc[(name, 'std')])

fig.legend(model_keys)
plt.show()

# %%
df = pd.read_pickle("acc_50p_0_lane_filter_f1.pkl")

# %% [markdown]
# #### F1 Score: trajectories with speed > 0 50% of time

# %%
df1 = df.loc[(slice(None),['f1_score','traj_len'],slice(None))]
df1
# Out:
#                                   50      100     150     200     250     300  \
# Random Forest  f1_score mean   58.571  57.199  57.031   56.82  56.714  54.557
#                         std     0.677   1.168   1.991   2.481   2.873   1.671
# AdaBoost       f1_score mean   56.209  55.809   55.36  56.568  54.059   53.35
#                         std     0.906   1.047   2.079   1.487   1.738   1.335
# SVM            f1_score mean   42.836  34.312   24.58  30.807  26.315  16.861
#                         std     1.297   2.142   2.043   5.894   2.698   2.566
# Log Regression f1_score mean    53.97  53.337  53.142  53.858  51.805  52.914
#                         std     0.625   1.279   1.089   1.449   1.795   1.493
# traj_len       traj_len total   19360    9376    6096    4428    3480    2860
#                         Car      9680    4688    3048    2214    1740    1430
#                         Taxi     9680    4688    3048    2214    1740    1430
#
#                                   350     400     450     500     550     600  \
# Random Forest  f1_score mean   56.393  56.147  56.904   55.85  56.449  56.434
#                         std     2.462    2.55   1.528   4.382   2.876   2.451
# AdaBoost       f1_score mean   53.337  55.829  56.253  55.365   57.46  54.589
#                         std     1.616   2.449   1.563    3.48   5.023   4.379
# SVM            f1_score mean    30.63  18.259  23.328  19.356  17.545  15.227
#                         std     8.985    4.94   9.195   5.198   5.101    5.06
# Log Regression f1_score mean   52.047  53.283  51.933  53.129  54.779  53.795
#                         std     2.985   1.369   3.367   2.422    4.36   5.585
# traj_len       traj_len total    2394    2060    1790    1528    1412    1300
#                         Car      1197    1030     895     764     706     650
#                         Taxi     1197    1030     895     764     706     650
#
#                                   650     700     750     800     850
# Random Forest  f1_score mean   55.604  54.929  57.153  55.794   57.44
#                         std     4.563     1.6   1.501   2.918   2.687
# AdaBoost       f1_score mean   56.547  51.318  53.409  55.537  52.167
#                         std      2.53   1.868   5.474   1.022   3.205
# SVM            f1_score mean    20.82   18.41  16.731  20.944  17.309
#                         std     6.004   5.438   9.325   8.555   5.116
# Log Regression f1_score mean   54.314  51.911  51.476  52.898  56.462
#                         std     3.989   3.788   1.935   2.895   3.303
# traj_len       traj_len total    1162    1058     946     848     798
#                         Car       581     529     473     424     399
#                         Taxi      581     529     473     424     399

# %%
fig,ax = plt.subplots(2)
df1 = df.loc[(slice(None),'f1_score',slice(None))]
fig.set_size_inches(8,10)
fig.set_dpi(80)
fig.tight_layout(h_pad=3)
fig.suptitle('F1_score vs. Trajectory Length')
plt.subplots_adjust(top=0.90)
model_keys = df1.index.get_level_values(0).unique()[0:4]

ax_mean, ax_std = ax

ax_mean.set_ylabel('Mean')
ax_std.set_ylabel('Std')

for i,name in enumerate(model_keys):
    ax_mean.plot(df1.columns, df1.loc[(name, 'mean')])
    ax_std.plot(df1.columns, df1.loc[(name, 'std')])

fig.legend(model_keys)
plt.show()

# %% [markdown]
# #### Accuracy: trajectories with speed > 0 50% of time

# %%
df1 = df.loc[(slice(None),['accuracy','traj_len'],slice(None))]
df1
# Out:
#                                   50      100     150     200     250     300  \
# Random Forest  accuracy mean   59.251  57.807  57.464  57.475  57.155  55.559
#                         std     0.632   0.667   1.477   1.762   2.101   1.091
# AdaBoost       accuracy mean   58.368  58.276  57.628  58.378  55.891  55.385
#                         std     0.627   0.711   1.569   1.225    1.04   0.979
# SVM            accuracy mean   54.437  53.125  51.985  52.958  52.644  51.189
#                         std     0.404   0.761   0.506   0.823   0.713   1.034
# Log Regression accuracy mean   57.268  57.103  56.972  57.408  56.236  55.769
#                         std      0.41   1.171   0.787   1.811   1.823   1.359
# traj_len       traj_len total   19360    9376    6096    4428    3480    2860
#                         Car      9680    4688    3048    2214    1740    1430
#                         Taxi     9680    4688    3048    2214    1740    1430
#
#                                   350     400     450     500     550     600  \
# Random Forest  accuracy mean    56.85  57.087  57.374   57.07  56.867    57.0
#                         std     2.599   2.647   1.866   3.104   2.855   1.363
# AdaBoost       accuracy mean   55.095  57.379  57.877  57.002  58.849    57.0
#                         std     1.402    2.59   1.661   2.302   4.556   3.562
# SVM            accuracy mean   52.256  52.233  52.793   51.31  51.275  51.385
#                         std       1.4   0.541   2.207    1.29   1.151   1.894
# Log Regression accuracy mean   55.471  56.942  57.095  57.263  59.209  58.308
#                         std     1.952   1.134   2.294   1.496   3.919   4.224
# traj_len       traj_len total    2394    2060    1790    1528    1412    1300
#                         Car      1197    1030     895     764     706     650
#                         Taxi     1197    1030     895     764     706     650
#
#                                   650     700     750     800     850
# Random Forest  accuracy mean   56.367  55.672  57.192  56.009  58.144
#                         std     3.864    1.55   1.858   2.228   1.862
# AdaBoost       accuracy mean   57.658  52.367  55.924  56.717  53.759
#                         std     2.728   2.006   2.899    2.22   2.331
# SVM            accuracy mean   51.721  51.327  51.587  51.888  52.506
#                         std     2.488   1.813    1.69   1.568   2.082
# Log Regression accuracy mean   58.087  55.952  56.341  56.366  60.155
#                         std     3.584   3.186   2.278   2.524   1.871
# traj_len       traj_len total    1162    1058     946     848     798
#                         Car       581     529     473     424     399
#                         Taxi      581     529     473     424     399

# %%
fig,ax = plt.subplots(2)
df1 = df.loc[(slice(None),'accuracy',slice(None))]
fig.set_size_inches(8,10)
fig.set_dpi(80)
fig.tight_layout(h_pad=3)
fig.suptitle('Accuracy vs. Trajectory Length')
plt.subplots_adjust(top=0.90)
model_keys = df1.index.get_level_values(0).unique()
ax_mean, ax_std = ax

ax_mean.set_ylabel('Mean')
ax_std.set_ylabel('Std')

for i,name in enumerate(model_keys):
    ax_mean.plot(df1.columns, df1.loc[(name, 'mean')])
    ax_std.plot(df1.columns, df1.loc[(name, 'std')])

fig.legend(model_keys)
plt.show()
